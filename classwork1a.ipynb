-- %%
SELECT TOP (1000) [DisciplineID]
      ,[Discipline]
      ,[SportID]
      ,[StudentID]
      ,[Edition]
  FROM [OLU].[dbo].[Discipines]
  WHERE StudentID='Oludayo Abiodun Adeoye';
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.169
-- <table><tr><th>DisciplineID</th><th>Discipline</th><th>SportID</th><th>StudentID</th><th>Edition</th></tr><tr><td>3</td><td>Gymnastics (Artistic)</td><td>20</td><td>Oludayo Abiodun Adeoye</td><td>2016</td></tr><tr><td>4</td><td>Athletics</td><td>3</td><td>Oludayo Abiodun Adeoye</td><td>2016</td></tr></table>

-- %% [markdown]
-- table 1

-- %%
SELECT TOP (1000) [EventID]
      ,[Event]
      ,[DisciplineID]
     
  FROM [OLU].[dbo].[Events]
-- Out:
-- Query was canceled by user
-- Query was canceled by user
-- Total execution time: 00:00:00.033
-- ...

-- %% [markdown]
-- table 2

-- %%
SELECT TOP (1000) [MedalistID]
      ,[Edition]
      ,[Athlete]
      ,[NOC]
      ,[Gender]
      ,[Event]
      ,[Medal]
      ,[Season]
      ,[MedalValue]
      ,[SportID]
      ,[DisciplineID]
  FROM [OLU].[dbo].[Medalist1]
-- Out:
-- (1000 rows affected)
-- Total execution time: 00:00:00.038
-- ...

-- %% [markdown]
-- table 3

-- %%
SELECT TOP (1000) [MedalistID]
      ,[Edition]
      ,[Athlete]
      ,[NOC]
      ,[Gender]
      ,[Event]
      ,[Medal]
      ,[Season]
      ,[MedalValue]
      ,[SportID]
      ,[DisciplineID]
  FROM [OLU].[dbo].[OlympicsData_SE-015 (oludayo)]
-- Out:
-- (1000 rows affected)
-- Total execution time: 00:00:00.084
-- ...

-- %% [markdown]
-- table 4

-- %%
SELECT TOP (1000) [Sport]
      ,[SportID]
  FROM [OLU].[dbo].[Sports]
-- Out:
-- (47 rows affected)
-- Total execution time: 00:00:00.008
-- ...

-- %% [markdown]
-- table 5
