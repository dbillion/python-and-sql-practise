-- %% [markdown]
-- this is the main

-- %%
SELECT TOP (1000) [MedalistID]
      ,[Edition]
      ,[Athlete]
      ,[NOC]
      ,[Gender]
      ,[Event]
      ,[Medal]
      ,[Season]
      ,[MedalValue]
      ,[SportID]
      ,[DisciplineID]
  FROM [OLU].[dbo].[OlympicsData_SE-015 (oludayo)]
-- Out:
-- (1000 rows affected)
-- Total execution time: 00:00:00.153
-- ...

-- %% [markdown]
-- this is my sport table

-- %%
SELECT TOP (1000) [EventID]
      ,[Event]
      ,[DisciplineID]
      ,[column4]
      ,[column5]
      ,[column6]
      ,[column7]
      ,[column8]
      ,[column9]
      ,[column10]
  FROM [OLU].[dbo].[Events]
-- Out:
-- (716 rows affected)
-- Total execution time: 00:00:00.048
-- ...

-- %% [markdown]
-- this is from my event table
